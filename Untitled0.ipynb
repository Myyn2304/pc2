# %%
import pandas as pd
link='https://github.com/Myyn2304/pc2/raw/refs/heads/main/HDI.xlsx'
table=pd.read_excel(link, header=4)
table
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   Unnamed: 3 Life expectancy at birth  \
# 0                            Value         NaN                  (years)
# ...

# %%
#las columnas de mi tabla, de las cuales solo me importan algunos
table.columns
# Out:
# Index(['Unnamed:_0', 'Unnamed:_1', 'Human_Development_Index_(HDI)',
#        'Unnamed:_3', 'Life_expectancy_at_birth', 'Unnamed:_5',
#        'Expected_years_of_schooling', 'Unnamed:_7', 'Mean_years_of_schooling',
#        'Unnamed:_9', 'Gross_national_income_(GNI)_per_capita', 'Unnamed:_11',
#        'GNI_per_capita_rank_minus_HDI_rank', 'Unnamed:_13', 'HDI_rank'],
#       dtype='object')

# %%
#quitar el espacio de los nombres cambiandolo por _ no sin antes str.strip() quita los espacios al
#inicio y final de cada nombre para que así no queden cosas como
#'Human_Development_Index_(HDI)_' sino 'Human_Development_Index_(HDI)'
table.columns=table.columns.str.strip().str.replace(r'\s+', '_', regex=True)
table.columns
# Out:
# Index(['Unnamed:_0', 'Unnamed:_1', 'Human_Development_Index_(HDI)',
#        'Unnamed:_3', 'Life_expectancy_at_birth', 'Unnamed:_5',
#        'Expected_years_of_schooling', 'Unnamed:_7', 'Mean_years_of_schooling',
#        'Unnamed:_9', 'Gross_national_income_(GNI)_per_capita', 'Unnamed:_11',
#        'GNI_per_capita_rank_minus_HDI_rank', 'Unnamed:_13', 'HDI_rank'],
#       dtype='object')

# %%
#eliminar las columnas que no sirven y/o que no son necesarias y las dos primeras filas
toDrop=['Unnamed:_0','Unnamed:_3','Unnamed:_5','Unnamed:_7','Unnamed:_9','Unnamed:_11','Unnamed:_13','GNI_per_capita_rank_minus_HDI_rank', 'HDI_rank']
table.drop(columns=toDrop,inplace=True)
table.drop(index=[0,1], inplace=True)

# %%
#cambiar nombres a los requeridos
nombre2={'Unnamed:_1':'Country','Human_Development_Index_(HDI)':'Human_Development_Index','Gross_national_income_(GNI)_per_capita':'Gross_national_income_per_capita'}
table.rename(columns=nombre2,inplace=True)
table.columns
# Out:
# Index(['Country', 'Human_Development_Index', 'Life_expectancy_at_birth',
#        'Expected_years_of_schooling', 'Mean_years_of_schooling',
#        'Gross_national_income_per_capita'],
#       dtype='object')

# %%
table
# Out:
#                                                Country  \
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 3                                          Switzerland
# 4                                               Norway
# 5                                              Iceland
# 6                               Hong Kong, China (SAR)
# ..                                                 ...
# 267                          Column 2: UNDESA (2022a).
# 268  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271  Column 6: Calculated based on data in columns ...
#
#     Human_Development_Index Life_expectancy_at_birth  \
# 2                       NaN                      NaN
# 3                     0.962                  83.9872
# 4                     0.961                  83.2339
# 5                     0.959                  82.6782
# ...

# %%
#comprobar si hay valores nan
table[table.isnull().any(axis=1)]
# Out:
#                                                Country  \
# 2                          VERY HIGH HUMAN DEVELOPMENT
# 69                              HIGH HUMAN DEVELOPMENT
# 119                           MEDIUM HUMAN DEVELOPMENT
# 164                              LOW HUMAN DEVELOPMENT
# 197                     OTHER COUNTRIES OR TERRITORIES
# 202                                                NaN
# 203                           Human development groups
# 208                                                NaN
# 210                                                NaN
# 211                                            Regions
# 218                                                NaN
# 221                                                NaN
# 223                                                NaN
# 225                                                NaN
# 226                                              Notes
# 227  a. Data refer to 2021 or the most recent year ...
# ...

# %%
#como sí hay filas con nan, procedemos a borrarlas
table=table.dropna(axis='rows',how='any',ignore_index=True)
table
# Out:
#                                                Country  \
# 0                                          Switzerland
# 1                                               Norway
# 2                                              Iceland
# 3                               Hong Kong, China (SAR)
# 4                                            Australia
# ..                                                 ...
# 205                                 Sub-Saharan Africa
# 206                          Least developed countries
# 207                     Small island developing states
# 208  Organisation for Economic Co-operation and Dev...
# 209                                              World
#
#     Human_Development_Index Life_expectancy_at_birth  \
# 0                     0.962                  83.9872
# 1                     0.961                  83.2339
# 2                     0.959                  82.6782
# 3                     0.952                  85.4734
# ...

# %%
#eliminando todas las filas que no sean países (las filas de abajo de Somalia)
table = table.drop(index=range(195, 210))
table
# Out:
#                                  Country Human_Development_Index  \
# 0                            Switzerland                   0.962
# 1                                 Norway                   0.961
# 2                                Iceland                   0.959
# 3                 Hong Kong, China (SAR)                   0.952
# 4                              Australia                   0.951
# ..                                   ...                     ...
# 190                          South Sudan                   0.385
# 191  Korea (Democratic People's Rep. of)                      ..
# 192                               Monaco                      ..
# 193                                Nauru                      ..
# 194                              Somalia                      ..
#
#     Life_expectancy_at_birth Expected_years_of_schooling  \
# 0                    83.9872                   16.500299
# 1                    83.2339                     18.1852
# ...

# %%
#qué tipo de dato es cada columna
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           195 non-null    object
#  1   Human_Development_Index           195 non-null    object
#  2   Life_expectancy_at_birth          195 non-null    object
#  3   Expected_years_of_schooling       195 non-null    object
#  4   Mean_years_of_schooling           195 non-null    object
#  5   Gross_national_income_per_capita  195 non-null    object
# dtypes: object(6)
# memory usage: 9.3+ KB

# %%
# se observa que el unico problema son los ".." de los ultimos 4 paises
pd.unique(table.Human_Development_Index[~table.Human_Development_Index.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['..'], dtype=object)

# %%
# en esta columna todos los valores encajan con valores numéricos
pd.unique(table.Life_expectancy_at_birth[~table.Life_expectancy_at_birth.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array([], dtype=object)

# %%
# se observa que el unico problema son los ".." de los ultimos 4 paises
pd.unique(table.Expected_years_of_schooling[~table.Expected_years_of_schooling.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['..'], dtype=object)

# %%
# se observa que el unico problema son los ".." de los ultimos 4 paises
pd.unique(table.Mean_years_of_schooling[~table.Mean_years_of_schooling.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['..'], dtype=object)

# %%
# se observa que el unico problema son los ".." de los ultimos 4 paises
pd.unique(table.Gross_national_income_per_capita[~table.Gross_national_income_per_capita.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['..'], dtype=object)

# %%
#transformar todos los valores a numeros en las tablas, se espera que los NaN esten en los ultimos 4 paises
table.Human_Development_Index=pd.to_numeric(table.Human_Development_Index,errors='coerce')
table.Life_expectancy_at_birth=pd.to_numeric(table.Life_expectancy_at_birth,errors='coerce')
table.Expected_years_of_schooling=pd.to_numeric(table.Expected_years_of_schooling,errors='coerce')
table.Mean_years_of_schooling=pd.to_numeric(table.Mean_years_of_schooling,errors='coerce')
table.Gross_national_income_per_capita=pd.to_numeric(table.Gross_national_income_per_capita,errors='coerce')
table
# Out:
#                                  Country  Human_Development_Index  \
# 0                            Switzerland                    0.962
# 1                                 Norway                    0.961
# 2                                Iceland                    0.959
# 3                 Hong Kong, China (SAR)                    0.952
# 4                              Australia                    0.951
# ..                                   ...                      ...
# 190                          South Sudan                    0.385
# 191  Korea (Democratic People's Rep. of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# ...

# %%
#se observa que ahora todos son numeros
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           195 non-null    object
#  1   Human_Development_Index           191 non-null    float64
#  2   Life_expectancy_at_birth          195 non-null    float64
#  3   Expected_years_of_schooling       193 non-null    float64
#  4   Mean_years_of_schooling           191 non-null    float64
#  5   Gross_national_income_per_capita  193 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.3+ KB

# %%
#creando la nueva categoria para clasificarlos en base a HDI
table['Category']=pd.cut(table.Human_Development_Index,
                           bins=[0,0.549,0.699,0.796,0.962],
                           labels=['LOW HUMAN DEVELOPMENT','MEDIUM HUMAN DEVELOPMENT','HIGH HUMAN DEVELOPMENT','VERY HIGH HUMAN DEVELOPMENT'],
                           ordered=True)
table
# Out:
#                                  Country  Human_Development_Index  \
# 0                            Switzerland                    0.962
# 1                                 Norway                    0.961
# 2                                Iceland                    0.959
# 3                 Hong Kong, China (SAR)                    0.952
# 4                              Australia                    0.951
# ..                                   ...                      ...
# 190                          South Sudan                    0.385
# 191  Korea (Democratic People's Rep. of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# ...

# %%
#si se desea retirar las finas de los ultimos 4 países por contener NaN se puede realizar con:
#table = table.drop(index=range(191, 194))
#O
#table=table.dropna(axis='rows',how='any',ignore_index=True)

# %%
#por si algún país no tiene mayúscula al inicio
table['Country']=table.Country.str.title()
table
# Out:
#                                  Country  Human_Development_Index  \
# 0                            Switzerland                    0.962
# 1                                 Norway                    0.961
# 2                                Iceland                    0.959
# 3                 Hong Kong, China (Sar)                    0.952
# 4                              Australia                    0.951
# ..                                   ...                      ...
# 190                          South Sudan                    0.385
# 191  Korea (Democratic People'S Rep. Of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# ...

# %%
#por sea caso en formato pickle, que es más eficiente al guardar datos tipo categorico
table.to_pickle("table.pkl")

# %%
#se observa se mantiene el tipo categorico
dfPickle=pd.read_pickle("table.pkl")
dfPickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           195 non-null    object
#  1   Human_Development_Index           191 non-null    float64
#  2   Life_expectancy_at_birth          195 non-null    float64
#  3   Expected_years_of_schooling       193 non-null    float64
#  4   Mean_years_of_schooling           191 non-null    float64
#  5   Gross_national_income_per_capita  193 non-null    float64
#  6   Category                          191 non-null    category
# dtypes: category(1), float64(5), object(1)
# memory usage: 9.5+ KB

# %%
#producto final
table
# Out:
#                                  Country  Human_Development_Index  \
# 0                            Switzerland                    0.962
# 1                                 Norway                    0.961
# 2                                Iceland                    0.959
# 3                 Hong Kong, China (Sar)                    0.952
# 4                              Australia                    0.951
# ..                                   ...                      ...
# 190                          South Sudan                    0.385
# 191  Korea (Democratic People'S Rep. Of)                      NaN
# 192                               Monaco                      NaN
# 193                                Nauru                      NaN
# 194                              Somalia                      NaN
#
#      Life_expectancy_at_birth  Expected_years_of_schooling  \
# 0                     83.9872                    16.500299
# ...
